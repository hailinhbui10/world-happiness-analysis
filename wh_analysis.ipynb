# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly
import plotly.graph_objs as go
import plotly.express as px
from plotly.subplots import make_subplots
from plotly.offline import iplot, init_notebook_mode

# %%
data = pd.read_csv(r"data\world-happiness-report-2021.csv")

# %%
data
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# 4                             0.027         7.518         7.410
# ..                              ...           ...           ...
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                   10.775           0.954                   72.000
# 1                   10.933           0.954                   72.700
# 2                   11.117           0.942                   74.400
# 3                   10.878           0.983                   73.000
# 4                   10.932           0.942                   72.400
# ..                     ...             ...                      ...
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# 146                  7.676           0.552                   61.400
# 147                  7.943           0.750                   56.201
# 148                  7.695           0.463                   52.493
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                           0.949      -0.098                      0.186
# 1                           0.946       0.030                      0.179
# 2                           0.919       0.025                      0.292
# 3                           0.955       0.160                      0.673
# 4                           0.913       0.175                      0.338
# ..                            ...         ...                        ...
# 144                         0.715      -0.131                      0.915
# 145                         0.824      -0.246                      0.801
# 146                         0.897       0.061                      0.167
# 147                         0.677      -0.047                      0.821
# 148                         0.382      -0.102                      0.924
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                        2.43                             1.446
# 1                        2.43                             1.502
# 2                        2.43                             1.566
# 3                        2.43                             1.482
# 4                        2.43                             1.501
# ..                        ...                               ...
# 144                      2.43                             0.451
# 145                      2.43                             1.099
# 146                      2.43                             0.364
# 147                      2.43                             0.457
# 148                      2.43                             0.370
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                           1.106                                  0.741
# 1                           1.108                                  0.763
# 2                           1.079                                  0.816
# 3                           1.172                                  0.772
# 4                           1.079                                  0.753
# ..                            ...                                    ...
# 144                         0.731                                  0.007
# 145                         0.724                                  0.340
# 146                         0.202                                  0.407
# 147                         0.649                                  0.243
# 148                         0.000                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                         0.691                     0.124
# 1                                         0.686                     0.208
# 2                                         0.653                     0.204
# 3                                         0.698                     0.293
# 4                                         0.647                     0.302
# ..                                          ...                       ...
# 144                                       0.405                     0.103
# 145                                       0.539                     0.027
# 146                                       0.627                     0.227
# 147                                       0.359                     0.157
# 148                                       0.000                     0.122
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 0                                      0.481                3.253
# 1                                      0.485                2.868
# 2                                      0.413                2.839
# 3                                      0.170                2.967
# 4                                      0.384                2.798
# ..                                       ...                  ...
# 144                                    0.015                1.800
# 145                                    0.088                0.648
# 146                                    0.493                1.095
# 147                                    0.075                1.205
# 148                                    0.010                1.895
#
# [149 rows x 20 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
#  9   Freedom to make life choices                149 non-null    float64
#  10  Generosity                                  149 non-null    float64
#  11  Perceptions of corruption                   149 non-null    float64
#  12  Ladder score in Dystopia                    149 non-null    float64
#  13  Explained by: Log GDP per capita            149 non-null    float64
#  14  Explained by: Social support                149 non-null    float64
#  15  Explained by: Healthy life expectancy       149 non-null    float64
#  16  Explained by: Freedom to make life choices  149 non-null    float64
#  17  Explained by: Generosity                    149 non-null    float64
#  18  Explained by: Perceptions of corruption     149 non-null    float64
#  19  Dystopia + residual                         149 non-null    float64
# dtypes: float64(18), object(2)
# memory usage: 23.4+ KB

# %%
data.describe().style.background_gradient(cmap = "RdPu")
# Out:
# <style type="text/css">
# #T_aa268_row0_col0, #T_aa268_row0_col1, #T_aa268_row0_col2, #T_aa268_row0_col3, #T_aa268_row0_col4, #T_aa268_row0_col5, #T_aa268_row0_col6, #T_aa268_row0_col7, #T_aa268_row0_col8, #T_aa268_row0_col9, #T_aa268_row0_col10, #T_aa268_row0_col11, #T_aa268_row0_col12, #T_aa268_row0_col13, #T_aa268_row0_col14, #T_aa268_row0_col15, #T_aa268_row0_col16, #T_aa268_row0_col17 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_aa268_row1_col0, #T_aa268_row1_col2, #T_aa268_row1_col3, #T_aa268_row5_col0, #T_aa268_row5_col2, #T_aa268_row5_col3 {
#   background-color: #fff2ee;
#   color: #000000;
# }
# #T_aa268_row1_col1, #T_aa268_row1_col8, #T_aa268_row1_col13, #T_aa268_row1_col14, #T_aa268_row1_col15, #T_aa268_row1_col16, #T_aa268_row2_col0, #T_aa268_row2_col1, #T_aa268_row2_col2, #T_aa268_row2_col3, #T_aa268_row2_col4, #T_aa268_row2_col5, #T_aa268_row2_col6, #T_aa268_row2_col7, #T_aa268_row2_col8, #T_aa268_row2_col9, #T_aa268_row2_col10, #T_aa268_row2_col11, #T_aa268_row2_col12, #T_aa268_row2_col13, #T_aa268_row2_col14, #T_aa268_row2_col15, #T_aa268_row2_col16, #T_aa268_row2_col17, #T_aa268_row3_col1, #T_aa268_row3_col5, #T_aa268_row3_col7, #T_aa268_row3_col8, #T_aa268_row3_col9, #T_aa268_row3_col11, #T_aa268_row3_col12, #T_aa268_row3_col13, #T_aa268_row3_col14, #T_aa268_row3_col15, #T_aa268_row3_col16, #T_aa268_row3_col17, #T_aa268_row4_col1, #T_aa268_row4_col8, #T_aa268_row4_col13, #T_aa268_row4_col14, #T_aa268_row4_col15, #T_aa268_row4_col16, #T_aa268_row5_col1, #T_aa268_row5_col8, #T_aa268_row5_col13, #T_aa268_row5_col14, #T_aa268_row5_col15, #T_aa268_row5_col16, #T_aa268_row6_col1, #T_aa268_row6_col8, #T_aa268_row6_col15, #T_aa268_row6_col16, #T_aa268_row7_col1, #T_aa268_row7_col15, #T_aa268_row7_col16 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_aa268_row1_col4, #T_aa268_row5_col4 {
#   background-color: #feede9;
#   color: #000000;
# }
# #T_aa268_row1_col5, #T_aa268_row1_col7, #T_aa268_row1_col9, #T_aa268_row1_col11, #T_aa268_row1_col12, #T_aa268_row3_col0, #T_aa268_row3_col2, #T_aa268_row3_col3, #T_aa268_row4_col5, #T_aa268_row4_col7, #T_aa268_row4_col9, #T_aa268_row4_col11, #T_aa268_row4_col12, #T_aa268_row4_col17, #T_aa268_row5_col5, #T_aa268_row5_col7, #T_aa268_row5_col9, #T_aa268_row5_col11, #T_aa268_row5_col12, #T_aa268_row6_col5, #T_aa268_row6_col7, #T_aa268_row6_col9, #T_aa268_row6_col11, #T_aa268_row6_col12, #T_aa268_row6_col13, #T_aa268_row6_col14, #T_aa268_row7_col5, #T_aa268_row7_col7, #T_aa268_row7_col8, #T_aa268_row7_col9, #T_aa268_row7_col12, #T_aa268_row7_col13, #T_aa268_row7_col14 {
#   background-color: #fff6f2;
#   color: #000000;
# }
# #T_aa268_row1_col6 {
#   background-color: #f991b0;
#   color: #000000;
# }
# #T_aa268_row1_col10, #T_aa268_row3_col10, #T_aa268_row4_col10, #T_aa268_row5_col10, #T_aa268_row6_col10, #T_aa268_row7_col10 {
#   background-color: #fff4f0;
#   color: #000000;
# }
# #T_aa268_row1_col17, #T_aa268_row5_col17, #T_aa268_row6_col17, #T_aa268_row7_col11 {
#   background-color: #fff5f1;
#   color: #000000;
# }
# #T_aa268_row3_col4, #T_aa268_row6_col0, #T_aa268_row6_col2, #T_aa268_row6_col3 {
#   background-color: #fef1ed;
#   color: #000000;
# }
# #T_aa268_row3_col6 {
#   background-color: #fbb8bc;
#   color: #000000;
# }
# #T_aa268_row4_col0, #T_aa268_row4_col2, #T_aa268_row4_col3 {
#   background-color: #fff3ef;
#   color: #000000;
# }
# #T_aa268_row4_col4 {
#   background-color: #feeeeb;
#   color: #000000;
# }
# #T_aa268_row4_col6 {
#   background-color: #faa0b5;
#   color: #000000;
# }
# #T_aa268_row5_col6 {
#   background-color: #f98bae;
#   color: #000000;
# }
# #T_aa268_row6_col4 {
#   background-color: #feebe8;
#   color: #000000;
# }
# #T_aa268_row6_col6 {
#   background-color: #f881aa;
#   color: #f1f1f1;
# }
# #T_aa268_row7_col0, #T_aa268_row7_col2, #T_aa268_row7_col3 {
#   background-color: #feefeb;
#   color: #000000;
# }
# #T_aa268_row7_col4 {
#   background-color: #feeae7;
#   color: #000000;
# }
# #T_aa268_row7_col6 {
#   background-color: #f76ba2;
#   color: #f1f1f1;
# }
# #T_aa268_row7_col17 {
#   background-color: #fff3f0;
#   color: #000000;
# }
# </style>
# <table id="T_aa268">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa268_level0_col0" class="col_heading level0 col0" >Ladder score</th>
#       <th id="T_aa268_level0_col1" class="col_heading level0 col1" >Standard error of ladder score</th>
#       <th id="T_aa268_level0_col2" class="col_heading level0 col2" >upperwhisker</th>
#       <th id="T_aa268_level0_col3" class="col_heading level0 col3" >lowerwhisker</th>
#       <th id="T_aa268_level0_col4" class="col_heading level0 col4" >Logged GDP per capita</th>
#       <th id="T_aa268_level0_col5" class="col_heading level0 col5" >Social support</th>
#       <th id="T_aa268_level0_col6" class="col_heading level0 col6" >Healthy life expectancy</th>
#       <th id="T_aa268_level0_col7" class="col_heading level0 col7" >Freedom to make life choices</th>
#       <th id="T_aa268_level0_col8" class="col_heading level0 col8" >Generosity</th>
#       <th id="T_aa268_level0_col9" class="col_heading level0 col9" >Perceptions of corruption</th>
#       <th id="T_aa268_level0_col10" class="col_heading level0 col10" >Ladder score in Dystopia</th>
#       <th id="T_aa268_level0_col11" class="col_heading level0 col11" >Explained by: Log GDP per capita</th>
#       <th id="T_aa268_level0_col12" class="col_heading level0 col12" >Explained by: Social support</th>
#       <th id="T_aa268_level0_col13" class="col_heading level0 col13" >Explained by: Healthy life expectancy</th>
#       <th id="T_aa268_level0_col14" class="col_heading level0 col14" >Explained by: Freedom to make life choices</th>
#       <th id="T_aa268_level0_col15" class="col_heading level0 col15" >Explained by: Generosity</th>
#       <th id="T_aa268_level0_col16" class="col_heading level0 col16" >Explained by: Perceptions of corruption</th>
#       <th id="T_aa268_level0_col17" class="col_heading level0 col17" >Dystopia + residual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa268_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_aa268_row0_col0" class="data row0 col0" >149.000000</td>
#       <td id="T_aa268_row0_col1" class="data row0 col1" >149.000000</td>
#       <td id="T_aa268_row0_col2" class="data row0 col2" >149.000000</td>
#       <td id="T_aa268_row0_col3" class="data row0 col3" >149.000000</td>
#       <td id="T_aa268_row0_col4" class="data row0 col4" >149.000000</td>
#       <td id="T_aa268_row0_col5" class="data row0 col5" >149.000000</td>
#       <td id="T_aa268_row0_col6" class="data row0 col6" >149.000000</td>
#       <td id="T_aa268_row0_col7" class="data row0 col7" >149.000000</td>
#       <td id="T_aa268_row0_col8" class="data row0 col8" >149.000000</td>
#       <td id="T_aa268_row0_col9" class="data row0 col9" >149.000000</td>
#       <td id="T_aa268_row0_col10" class="data row0 col10" >149.000000</td>
#       <td id="T_aa268_row0_col11" class="data row0 col11" >149.000000</td>
#       <td id="T_aa268_row0_col12" class="data row0 col12" >149.000000</td>
#       <td id="T_aa268_row0_col13" class="data row0 col13" >149.000000</td>
#       <td id="T_aa268_row0_col14" class="data row0 col14" >149.000000</td>
#       <td id="T_aa268_row0_col15" class="data row0 col15" >149.000000</td>
#       <td id="T_aa268_row0_col16" class="data row0 col16" >149.000000</td>
#       <td id="T_aa268_row0_col17" class="data row0 col17" >149.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aa268_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_aa268_row1_col0" class="data row1 col0" >5.532839</td>
#       <td id="T_aa268_row1_col1" class="data row1 col1" >0.058752</td>
#       <td id="T_aa268_row1_col2" class="data row1 col2" >5.648007</td>
#       <td id="T_aa268_row1_col3" class="data row1 col3" >5.417631</td>
#       <td id="T_aa268_row1_col4" class="data row1 col4" >9.432208</td>
#       <td id="T_aa268_row1_col5" class="data row1 col5" >0.814745</td>
#       <td id="T_aa268_row1_col6" class="data row1 col6" >64.992799</td>
#       <td id="T_aa268_row1_col7" class="data row1 col7" >0.791597</td>
#       <td id="T_aa268_row1_col8" class="data
